# %% [markdown]
# **PANDAS** **24-02-2024**

# %%
import pandas as pd
a=["Jwalitha","Ramya",'durga','Jahnavi','lahari',',sunny','dhanush']
r=pd.Series(a,index=[67,43,44,89,34,45,23])
print(r)
# Out:
# 67    Jwalitha
# 43       Ramya
# 44       durga
# 89     Jahnavi
# 34      lahari
# 45      ,sunny
# 23     dhanush
# dtype: object

# %%
df=pd.read_csv("/content/diabetcsv.csv")
print(df)

# %%
df=pd.read_csv("/content/grades_withnulls.csv",sep=" ")
print(df)
# Out:
#    Names,Initials,SEM1,SEM2,SEM3,Grade,Placed
# 0                       Joe,K,9.8,10,9.9,A+,1
# 1                    Rajesh,M,8.9,9.1,9.3,A,1
# 2                     Kissan,V,9.9,9.8,10,A,0
# 3                        Mary,N,7.7,8,NaN,B,0
# 4                     Jeen,K,9.8,9.1,9.9,A+,1
# 5                       Raj,M,8.9,9.1,9.3,A,1
# 6                      Hassan,V,9.9,9,9.2,A,1
# 7                        Mari,N,7.7,8,7.1,B,1
# 8                     Jess,K,NaN,9.1,9.9,A+,1
# 9                    Rajini,M,NaN,9.1,9.3,A,0
# 10                    Kiran,V,NaN,9.3,9.2,A,0
# 11                       Maya,N,7.7,8,7.1,B,0
# 12                   Jolin,K,9.8,9.1,9.9,A+,1
# 13                   Rajesh,M,8.9,9.1,9.3,A,1
# 14                      Riya,M,9.3,9.9,10,A,1
# 15                     Sana,V,9.9,9.3,9.2,A,0
# 16                         Mark,N,7.7,8,7,B,0

# %%
df=pd.read_excel("/content/diabet.xlsx")
print(df)
df=pd.read_excel("/content/diabet.xlsx",sheet_name=1)
print(df)
# Out:
#      preg  plas  pres  skin  insu  mass   pedi  age            class
# 0       6   148    72    35     0  33.6  0.627   50  tested_positive
# 1       1    85    66    29     0  26.6  0.351   31  tested_negative
# 2       8   183    64     0     0  23.3  0.672   32  tested_positive
# 3       1    89    66    23    94  28.1  0.167   21  tested_negative
# 4       0   137    40    35   168  43.1  2.288   33  tested_positive
# ..    ...   ...   ...   ...   ...   ...    ...  ...              ...
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative
#
# [768 rows x 9 columns]
#      6  148  72  35    0  33.6  0.627  50  tested_positive
# 0    1   85  66  29    0  26.6  0.351  31  tested_negative
# 1    8  183  64   0    0  23.3  0.672  32  tested_positive
# 2    1   89  66  23   94  28.1  0.167  21  tested_negative
# 3    0  137  40  35  168  43.1  2.288  33  tested_positive
# 4    5  116  74   0    0  25.6  0.201  30  tested_negative
# 5    3   78  50  32   88  31.0  0.248  26  tested_positive
# 6   10  115   0   0    0  35.3  0.134  29  tested_negative
# 7    2  197  70  45  543  30.5  0.158  53  tested_positive
# 8    8  125  96   0    0   0.0  0.232  54  tested_positive
# 9    4  110  92   0    0  37.6  0.191  30  tested_negative
# 10  10  168  74   0    0  38.0  0.537  34  tested_positive
# 11  10  139  80   0    0  27.1  1.441  57  tested_negative

# %%
df=pd.read_csv("/content/grades_withnulls.csv")
print(df.head())
print(df.tail(10))
# Out:
#     Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0     Joe        K   9.8  10.0   9.9    A+       1
# 1  Rajesh        M   8.9   9.1   9.3     A       1
# 2  Kissan        V   9.9   9.8  10.0     A       0
# 3    Mary        N   7.7   8.0   NaN     B       0
# 4    Jeen        K   9.8   9.1   9.9    A+       1
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
df=pd.read_csv("/content/grades_withnulls.csv")
print(df.describe)
# Out:
# <bound method NDFrame.describe of      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   NaN     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0>

# %%
print(df.describe().T)
print(df.shape)
print(df.shape[0])
print(df.shape[1])
# Out:
#         count      mean       std  min  25%  50%  75%   max
# SEM1     14.0  8.992857  0.929404  7.7  8.0  9.1  9.8   9.9
# SEM2     17.0  9.000000  0.647109  8.0  9.0  9.1  9.3  10.0
# SEM3     16.0  9.100000  1.057670  7.0  9.2  9.3  9.9  10.0
# Placed   17.0  0.588235  0.507300  0.0  0.0  1.0  1.0   1.0
# (17, 7)
# 17
# 7

# %%
df=pd.read_csv("/content/grades_withnulls.csv")
print(df.columns)
list1=list(df)
print(list1)
df2=df.copy()
df2.loc[2:5,'sem1']=None
df2.head(7)
df2.loc[2:5,'sem1']=7
df2.head(7)
df2.isnull().head(7)
df2.isnull().tail(7)
print(df2.isnull().sum())
# Out:
# Index(['Names', 'Initials', 'SEM1', 'SEM2', 'SEM3', 'Grade', 'Placed'], dtype='object')
# ['Names', 'Initials', 'SEM1', 'SEM2', 'SEM3', 'Grade', 'Placed']
# Names        0
# Initials     0
# SEM1         3
# SEM2         0
# SEM3         1
# Grade        0
# Placed       0
# sem1        13
# dtype: int64

# %%
df=pd.read_csv("/content/grades_withnulls.csv")
#Extracting the colummn
print(df['SEM1'])
# Out:
# 0     9.8
# 1     8.9
# 2     9.9
# 3     7.7
# 4     9.8
# 5     8.9
# 6     9.9
# 7     7.7
# 8     NaN
# 9     NaN
# 10    NaN
# 11    7.7
# 12    9.8
# 13    8.9
# 14    9.3
# 15    9.9
# 16    7.7
# Name: SEM1, dtype: float64

# %%
print(df2[['SEM1','Names']])
# Out:
#     SEM1   Names
# 0    9.8     Joe
# 1    8.9  Rajesh
# 2    9.9  Kissan
# 3    7.7    Mary
# 4    9.8    Jeen
# 5    8.9     Raj
# 6    9.9  Hassan
# 7    7.7    Mari
# 8    NaN    Jess
# 9    NaN  Rajini
# 10   NaN   Kiran
# 11   7.7    Maya
# 12   9.8   Jolin
# 13   8.9  Rajesh
# 14   9.3    Riya
# 15   9.9    Sana
# 16   7.7    Mark

# %%
print(df[df.index==1])
print(df[df.index.isin(range(2,5))])
print(df2.loc[3])
df2.loc[6:11]
df.loc[6:11,'SEM1']==None
df2.loc[[10,2,7]]
df2.loc[[1,2,3]]
# Out:
#     Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 1  Rajesh        M   8.9   9.1   9.3     A       1
#     Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 2  Kissan        V   9.9   9.8  10.0     A       0
# 3    Mary        N   7.7   8.0   NaN     B       0
# 4    Jeen        K   9.8   9.1   9.9    A+       1
# Names       Mary
# Initials       N
# SEM1         7.7
# SEM2         8.0
# SEM3         NaN
# Grade          B
# Placed         0
# sem1         7.0
# Name: 3, dtype: object
#     Names Initials  SEM1  SEM2  SEM3 Grade  Placed  sem1
# 1  Rajesh        M   8.9   9.1   9.3     A       1   NaN
# 2  Kissan        V   9.9   9.8  10.0     A       0   7.0
# 3    Mary        N   7.7   8.0   NaN     B       0   7.0

# %%
df2.loc[6:11]
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed  sem1
# 6   Hassan        V   9.9   9.0   9.2     A       1   NaN
# 7     Mari        N   7.7   8.0   7.1     B       1   NaN
# 8     Jess        K   NaN   9.1   9.9    A+       1   NaN
# 9   Rajini        M   NaN   9.1   9.3     A       0   NaN
# 10   Kiran        V   NaN   9.3   9.2     A       0   NaN
# 11    Maya        N   7.7   8.0   7.1     B       0   NaN

# %%
df2.loc[10:15,['Names','Grade']]
# Out:
#      Names Grade
# 10   Kiran     A
# 11    Maya     B
# 12   Jolin    A+
# 13  Rajesh     A
# 14    Riya     A
# 15    Sana     A

# %%
df2.iloc[10:14, :3]#row, column
# Out:
#      Names Initials  SEM1
# 10   Kiran        V   NaN
# 11    Maya        N   7.7
# 12   Jolin        K   9.8
# 13  Rajesh        M   8.9

# %%
df2.loc[:6,["Names"]]
# Out:
#     Names
# 0     Joe
# 1  Rajesh
# 2  Kissan
# 3    Mary
# 4    Jeen
# 5     Raj
# 6  Hassan

# %%
df2.loc[df['Names']=='Rajesh']
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed  sem1
# 1   Rajesh        M   8.9   9.1   9.3     A       1   NaN
# 13  Rajesh        M   8.9   9.1   9.3     A       1   NaN

# %%
df[df.Grade=="A"]
df[df.SEM2==10]
df.loc[df['SEM1']>9.8,['Names']]
# Out:
#      Names
# 2   Kissan
# 6   Hassan
# 15    Sana

# %%
df2.loc[:6]
# Out:
#     Names Initials  SEM1  SEM2  SEM3 Grade  Placed  sem1
# 0     Joe        K   9.8  10.0   9.9    A+       1   NaN
# 1  Rajesh        M   8.9   9.1   9.3     A       1   NaN
# 2  Kissan        V   9.9   9.8  10.0     A       0   7.0
# 3    Mary        N   7.7   8.0   NaN     B       0   7.0
# 4    Jeen        K   9.8   9.1   9.9    A+       1   7.0
# 5     Raj        M   8.9   9.1   9.3     A       1   7.0
# 6  Hassan        V   9.9   9.0   9.2     A       1   NaN

# %%
df3=df2.copy()
df3
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed  sem1
# 0      Joe        K   9.8  10.0   9.9    A+       1   NaN
# 1   Rajesh        M   8.9   9.1   9.3     A       1   NaN
# 2   Kissan        V   9.9   9.8  10.0     A       0   7.0
# 3     Mary        N   7.7   8.0   NaN     B       0   7.0
# 4     Jeen        K   9.8   9.1   9.9    A+       1   7.0
# 5      Raj        M   8.9   9.1   9.3     A       1   7.0
# 6   Hassan        V   9.9   9.0   9.2     A       1   NaN
# 7     Mari        N   7.7   8.0   7.1     B       1   NaN
# 8     Jess        K   NaN   9.1   9.9    A+       1   NaN
# 9   Rajini        M   NaN   9.1   9.3     A       0   NaN
# 10   Kiran        V   NaN   9.3   9.2     A       0   NaN
# 11    Maya        N   7.7   8.0   7.1     B       0   NaN
# 12   Jolin        K   9.8   9.1   9.9    A+       1   NaN
# 13  Rajesh        M   8.9   9.1   9.3     A       1   NaN
# 14    Riya        M   9.3   9.9  10.0     A       1   NaN
# 15    Sana        V   9.9   9.3   9.2     A       0   NaN
# 16    Mark        N   7.7   8.0   7.0     B       0   NaN

# %%
df3.dropna(inplace=True,axis=1)#drop the columns which are having null values
df3
# Out:
#      Names Initials  SEM2 Grade  Placed
# 0      Joe        K  10.0    A+       1
# 1   Rajesh        M   9.1     A       1
# 2   Kissan        V   9.8     A       0
# 3     Mary        N   8.0     B       0
# 4     Jeen        K   9.1    A+       1
# 5      Raj        M   9.1     A       1
# 6   Hassan        V   9.0     A       1
# 7     Mari        N   8.0     B       1
# 8     Jess        K   9.1    A+       1
# 9   Rajini        M   9.1     A       0
# 10   Kiran        V   9.3     A       0
# 11    Maya        N   8.0     B       0
# 12   Jolin        K   9.1    A+       1
# 13  Rajesh        M   9.1     A       1
# 14    Riya        M   9.9     A       1
# 15    Sana        V   9.3     A       0
# 16    Mark        N   8.0     B       0

# %%
df3.dropna(inplace=True,how='all')
df3
# Out:
#      Names Initials  SEM2 Grade  Placed
# 0      Joe        K  10.0    A+       1
# 1   Rajesh        M   9.1     A       1
# 2   Kissan        V   9.8     A       0
# 3     Mary        N   8.0     B       0
# 4     Jeen        K   9.1    A+       1
# 5      Raj        M   9.1     A       1
# 6   Hassan        V   9.0     A       1
# 7     Mari        N   8.0     B       1
# 8     Jess        K   9.1    A+       1
# 9   Rajini        M   9.1     A       0
# 10   Kiran        V   9.3     A       0
# 11    Maya        N   8.0     B       0
# 12   Jolin        K   9.1    A+       1
# 13  Rajesh        M   9.1     A       1
# 14    Riya        M   9.9     A       1
# 15    Sana        V   9.3     A       0
# 16    Mark        N   8.0     B       0

# %%
mv=df3['SEM2'].mean()
print(mv)
# Out:
# 9.0

# %%
df3=df3.fillna(mv)
print(df3)
# Out:
#      Names Initials  SEM2 Grade  Placed
# 0      Joe        K  10.0    A+       1
# 1   Rajesh        M   9.1     A       1
# 2   Kissan        V   9.8     A       0
# 3     Mary        N   8.0     B       0
# 4     Jeen        K   9.1    A+       1
# 5      Raj        M   9.1     A       1
# 6   Hassan        V   9.0     A       1
# 7     Mari        N   8.0     B       1
# 8     Jess        K   9.1    A+       1
# 9   Rajini        M   9.1     A       0
# 10   Kiran        V   9.3     A       0
# 11    Maya        N   8.0     B       0
# 12   Jolin        K   9.1    A+       1
# 13  Rajesh        M   9.1     A       1
# 14    Riya        M   9.9     A       1
# 15    Sana        V   9.3     A       0
# 16    Mark        N   8.0     B       0

# %%
df3=df3.drop_duplicates()
print(df3)
# Out:
#      Names Initials  SEM2 Grade  Placed
# 0      Joe        K  10.0    A+       1
# 1   Rajesh        M   9.1     A       1
# 2   Kissan        V   9.8     A       0
# 3     Mary        N   8.0     B       0
# 4     Jeen        K   9.1    A+       1
# 5      Raj        M   9.1     A       1
# 6   Hassan        V   9.0     A       1
# 7     Mari        N   8.0     B       1
# 8     Jess        K   9.1    A+       1
# 9   Rajini        M   9.1     A       0
# 10   Kiran        V   9.3     A       0
# 11    Maya        N   8.0     B       0
# 12   Jolin        K   9.1    A+       1
# 14    Riya        M   9.9     A       1
# 15    Sana        V   9.3     A       0
# 16    Mark        N   8.0     B       0

# %%
df3.rename(columns={'Grade':'Gpa'},inplace=True)
print(df3)
# Out:
#      Names Initials  SEM2 Gpa  Placed
# 0      Joe        K  10.0  A+       1
# 1   Rajesh        M   9.1   A       1
# 2   Kissan        V   9.8   A       0
# 3     Mary        N   8.0   B       0
# 4     Jeen        K   9.1  A+       1
# 5      Raj        M   9.1   A       1
# 6   Hassan        V   9.0   A       1
# 7     Mari        N   8.0   B       1
# 8     Jess        K   9.1  A+       1
# 9   Rajini        M   9.1   A       0
# 10   Kiran        V   9.3   A       0
# 11    Maya        N   8.0   B       0
# 12   Jolin        K   9.1  A+       1
# 14    Riya        M   9.9   A       1
# 15    Sana        V   9.3   A       0
# 16    Mark        N   8.0   B       0
